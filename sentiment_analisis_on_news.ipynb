pm</span> on <span clas="date">30 Nov 2020,Monday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">The Football Association is investigating Manchester United striker Edinson Cavani's social media post which uses 'negrito' term. The post, which has not been deleted, was published shortly after United's 3-2 win against Southampton, in which Cavani scored two goals after coming on as a half-time substitute. Luis Suarez had got an eight-match ban for using the same word in 2011. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/fa-to-look-into-man-utds-cavanis-social-media-post-which-uses-negrito-term-1606749529556"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2020-11-30T15:18:49.000Z" itemprop="dateModified">08:48 pm</span> on <span class="date">30 Nov</span>
# </div>
# </div>
# </div>
# </div>
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/virat-kohli-is-being-hasty-in-his-decisions-ashish-nehra-1606732303430" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Ankur Taliyan" itemprop="name"></span>
# </span>
# <span content="Virat Kohli is being hasty in his decisions: Ashish Nehra" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/30_mon/img_1606729611819_438.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# <span itemprop="publisher" itemscope="itemscope" itemtype="https://schema.org/Organization">
# <span content="https://inshorts.com/" itemprop="url"></span>
# <span content="Inshorts" itemprop="name"></span>
# <span itemprop="logo" itemscope="" itemtype="https://schema.org/ImageObject">
# <span content="https://assets.inshorts.com/inshorts/images/v1/variants/jpg/m/2018/11_nov/21_wed/img_1542823931298_497.jpg" itemprop="url"></span>
# <meta content="400" itemprop="width"/>
# <meta content="60" itemprop="height"/>
# </span>
# </span>
# <div class="news-card-image" style="background-image: url('https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2020/11_nov/30_mon/img_1606729611819_438.jpg?')">
# </div>
# <div class="news-card-title news-right-box">
# <a class="clickable" href="/en/news/virat-kohli-is-being-hasty-in-his-decisions-ashish-nehra-1606732303430" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'TitleOfNews', 'eventAction': 'clicked', 'eventLabel': 'Virat%20Kohli%20is%20being%20hasty%20in%20his%20decisions%3A%20Ashish%20Nehra)' });" style="color:#44444d!important">
# <span itemprop="headline">Virat Kohli is being hasty in his decisions: Ashish Nehra</span>
# </a>
# <div class="news-card-author-time news-card-author-time-in-title">
# <a href="/prev/en/news/virat-kohli-is-being-hasty-in-his-decisions-ashish-nehra-1606732303430"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2020-11-30T10:31:43.000Z" itemprop="datePublished">04:01 pm</span> on <span clas="date">30 Nov 2020,Monday</span>
# </div>
# </div>
# <div class="news-card-content news-right-box">
# <div itemprop="articleBody">Talking about Virat Kohli's captaincy in the second ODI against Australia, former India pacer Ashish Nehra said that the India skipper was being hasty in his decisions. "Kohli is an impulsive captain. He is making too many changes in his bowling. And this is an area that he needs to take care of," Nehra added. </div>
# <div class="news-card-author-time news-card-author-time-in-content">
# <a href="/prev/en/news/virat-kohli-is-being-hasty-in-his-decisions-ashish-nehra-1606732303430"><span class="short">short</span></a> by <span class="author">Ankur Taliyan</span> /
#       <span class="time" content="2020-11-30T10:31:43.000Z" itemprop="dateModified">04:01 pm</span> on <span class="date">30 Nov</span>
# </div>
# </div>
# <div class="news-card-footer news-right-box">
# <div class="read-more">read more at <a class="source" href="https://www.sportskeeda.com/amp/cricket/ind-v-aus-2020-virat-kohli-hasty-decisions-ashish-nehra-points-flaws-indian-captain-s-tactics?utm_campaign=fullarticle&amp;utm_medium=referral&amp;utm_source=inshorts " onclick="ga('send', {'hitType': 'event', 'eventCategory': 'ReadMore', 'eventAction': 'clicked', 'eventLabel': 'Sportskeeda' });" target="_blank">Sportskeeda</a></div>
# </div>
# </div>
# </div>
# </div>
# <div class="load-more-wrapper">
# <div class="clickable unselectable load-more z-depth-1 hoverable" id="load-more-btn" onclick="loadMoreNews()">Load More</div>
# <div class="clickable unselectable load-more" id="load-more-gif" style="display:none;"><img id="load-more-gif" src="https://assets.inshorts.com/website_assets/images/ajax-loader.gif"/></div>
# </div>
# <div class="my-red app-download-pane hide-on-large-only">
# <div class="container">
# <div class="row">
# <div class="col s12 center" style="color:white;font-weight: 300;font-size:14px;margin-top: 28px;margin-bottom: 18px;">
#               For the best experience use <a href="/mobile" style="color:white;appearance: none;font-weight: 500;" target="_blank">inshorts</a> app on your smartphone
#             </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- BODY END -->
# <footer class="page-footer teals">
# <div class="container">
# <div class="row" style="margin-bottom: 0px; padding-bottom: 5px;">
# <div class="col offset-l3 l3 m4 s12 right social-admin">
# <div class="social-share"><a href="https://www.facebook.com/inshortsapp" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToFaceBookPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToFaceBook' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/facebook.png"/></a></div>
# <div class="social-share"><a href="https://twitter.com/inshorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTwitterPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTwitter' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/twitter.png"/></a></div>
# <div class="social-share"><a href="https://www.linkedin.com/company/news-in-shorts" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToLinkedinPage', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToLinkedin' });" target="_blank"><img src="https://assets.inshorts.com/website_assets/images/linkedin.png"/></a></div>
# </div>
# <div class="col m4 l3 s6 footer-left-pane">
# <div class="right"><img height="48px" src="https://assets.inshorts.com/website_assets/images/logo_footer.png" width="160px"/></div>
# <div class="copy-text">
# <span><span style="color:#cfcfcf;font-family: 'Conv_ClanPro-Bold'">inshorts</span> medialabs pvt. ltd.</span><br/>
#           ©<span style="font-size:12px">COPYRIGHT 2020</span>
# </div>
# </div>
# <div class="col m4 l3 s6 footer-right-pane">
# <div class="left clickable" id="contactUsBtn" style="margin-top: -5px;"><img height="48px" src="https://assets.inshorts.com/website_assets/images/contact_icon.png" width="132px"/></div>
# <div class="terms-text">
# <a class="tnc" href="/tnc" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToTermsAndConditionsAndPP', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToTermsAndConditions' });" style="color: #fff;" target="_blank"><span>Terms &amp; conditions</span><br/>
# <span>Privacy Policies</span>
# </a>
# <br/>
# <a class="tnc" href="/editorial_policy" onclick="ga('send', {'hitType': 'event', 'eventCategory': 'LinkToSitemap', 'eventAction': 'clicked', 'eventLabel': 'RedirectedToSitemap' });" style="color: #fff;" target="_blank">
# <span>Editorial Policy</span>
# </a>
# </div>
# </div>
# </div>
# </div>
# <div class="modal_contact row" id="contactUsModal">
# <!-- Modal content -->
# <div class="modal-content col l4 m4 s8 offset-s2 offset-l4 offset-m4">
# <span class="close">×</span>
# <div class="contact">
# <a href="mailto:careers@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Hiring Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Admin@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Admin Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Marketing@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Marketing Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Editorial@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Editorial Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Sales@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact Sales Team</button>
# </a>
# </div>
# <div class="contact">
# <a href="mailto:Contact@inshorts.com?subject=Inshorts%20website%20contact%20form" target="_blank">
# <button id="myBtn">Contact For Any Other Query</button>
# </a>
# </div>
# </div>
# </div>
# </footer>
# <script>
# var modal = document.getElementById('contactUsModal');
#
# // Get the button that opens the modal
# var btn = document.getElementById("contactUsBtn");
#
# // Get the <span> element that closes the modal
# var span = document.getElementsByClassName("close")[0];
#
# // When the user clicks on the button, open the modal
# btn.onclick = function() {
#     modal.style.display = "block";
# }
#
# // When the user clicks on <span> (x), close the modal
# span.onclick = function() {
#     modal.style.display = "none";
# }
#
# // When the user clicks anywhere outside of the modal, close it
# window.onclick = function(event) {
#     if (event.target == modal) {
#         modal.style.display = "none";
#     }
# }
# </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8/jquery.min.js"></script>
# <script src="https://cdnjs.cloudflare.com/ajax/libs/materialize/0.97.0/js/materialize.min.js"></script>
# <script src="/dist/scripts/index.js" type="text/javascript"></script>
# <script src="/dist/scripts/read.js" type="text/javascript"></script>
# <script src="/dist/scripts/jquery.scrolldepth.min.js"></script>
# <script type="text/javascript">
#
#     var min_news_id = "kjfqglei-1";
#     function loadMoreNews(){
#       $("#load-more-btn").hide();
#       $("#load-more-gif").show();
#       $.post("/en/ajax/more_news",{'category':'sports','news_offset':min_news_id},function(data){
#           data = JSON.parse(data);
#           min_news_id = data.min_news_id||min_news_id;
#           $(".card-stack").append(data.html);
#       })
#       .fail(function(){alert("Error : unable to load more news");})
#       .always(function(){$("#load-more-btn").show();$("#load-more-gif").hide();});
#     }
#     jQuery.scrollDepth();
#   </script>
# <!-- Eliminate render-blocking JavaScript and CSS in above-the-fold content -->
# </body>
# </html>

# %%
urls=['https://inshorts.com/en/read/sports',
      'https://inshorts.com/en/read/world',
      'https://inshorts.com/en/read/politics']
def build_dataset(urls) :
  news_data=[]
  for url in urls :
    news_category=url.split('/')[-1]
    data=requests.get(url)
    soup=BeautifulSoup(data.content)

    news_articles=[{'news_headline':headline.find('span',attrs={"itemprop":"headline"}).string,
                   'news_article':article.find('div',attrs={"itemprop":"articleBody"}).string,
                    'news_category':news_category}
                   
                   for headline,article in zip(soup.find_all('div',class_=["news-card-title news-right-box"]),
                                               soup.find_all('div',class_=["news-card-content news-right-box"]))]
    news_articles = news_articles[0:20]
    news_data.extend(news_articles)

  df = pd.DataFrame(news_data)
  df = df [['news_headline','news_article','news_category']]
  return df

# %%
df= build_dataset(urls)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  Didn’t ask for paternity leave, my wife backed...  ...        sports
# 1  Chris Lynn smashes 20 sixes, scores 154 runs o...  ...        sports
# 2  It would be nicer if Warner gets injured for a...  ...        sports
# 3  No captain would give Bumrah 2-over opening sp...  ...        sports
# 4  Tyson reveals he smoked marijuana before throw...  ...        sports
#
# [5 rows x 3 columns]

# %%
df= build_dataset(urls)
df.tail()
# Out:
#                                         news_headline  ... news_category
# 55  BJP rolls out red carpet for billionaires, dig...  ...      politics
# 56  Never called farmers' protest politically moti...  ...      politics
# 57  Shah's promise to free Hyd from Nizami culture...  ...      politics
# 58  President Kovind, PM Modi extend greetings on ...  ...      politics
# 59  Farmers made positive contribution to GDP, ret...  ...      politics
#
# [5 rows x 3 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/gkesavamurthy/basics/main/news.csv')
df
# Out:
#                                         news_headline  ... news_category
# 0   Didn’t ask for paternity leave, my wife backed...  ...        sports
# 1   It annoys the hell out of me: Ian Chappell urg...  ...        sports
# 2   F1 driver survives huge crash after car splits...  ...        sports
# 3   Maradona’s doctor probed over involuntary mans...  ...        sports
# 4   Chris Lynn smashes 20 sixes, scores 154 runs o...  ...        sports
# 5   Referee saves MMA fighter from nearly flashing...  ...        sports
# 6   Jasprit Bumrah kicks 30-yard field marker in a...  ...        sports
# 7   What protection do farmers have: Monty Panesar...  ...        sports
# 8   Tyson reveals he smoked marijuana before throw...  ...        sports
# %%
import nltk
nltk.download('stopwords')
stopword_list = nltk.corpus.stopwords.words('english')
stopword_list.remove('no')
stopword_list.remove('not')
len(stopword_list)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 177

# %%
def html_tag(text):
  soup = BeautifulSoup(text,"html.parser")
  new_text =soup.get_text()
  return new_text

html_tag('<html><h2> some important info </h2></html>')
# Out:
# ' some important info '

# %%
# !pip install contractions
import contractions
def con(text):
   expand = contractions.fix(text)
   return expand
# Out:
# Requirement already satisfied: contractions in /usr/local/lib/python3.6/dist-packages (0.0.25)
# Requirement already satisfied: textsearch in /usr/local/lib/python3.6/dist-packages (from contractions) (0.0.17)
# Requirement already satisfied: pyahocorasick in /usr/local/lib/python3.6/dist-packages (from textsearch->contractions) (1.4.0)
# Requirement already satisfied: Unidecode in /usr/local/lib/python3.6/dist-packages (from textsearch->contractions) (1.1.1)

# %%
import re
def remove_sp(text):
  pattern = r'[^A-Za-z0-9]'
  text=re.sub(pattern,'',text)
  return text

# %%
from nltk.tokenize.toktok import ToktokTokenizer
tokenizer = ToktokTokenizer()

# %%
def remove_stopwords(text):
  tokens = tokenizer.tokenize(text)
  tokens = [token.strip() for token in tokens]
  filtered_tokens = [token for token in tokens if token not in  stopword_list]
  filtered_text = ''.join(filtered_tokens)
  return filtered_text

# %%
df.news_headline = df.news_headline.apply(lambda x:x.lower())
df.news_article = df.news_article.apply(lambda x:x.lower())

df.news_headline = df.news_headline.apply(html_tag)
df.news_article = df.news_article.apply(html_tag)

df.news_headline = df.news_headline.apply(con)
df.news_article = df.news_article.apply(con)

df.news_headline = df.news_headline.apply(remove_sp)
df.news_article = df.news_article.apply(remove_sp)

df.news_headline = df.news_headline.apply(remove_stopwords)
df.news_article = df.news_article.apply(remove_stopwords)
df.head()
# Out:
#                                        news_headline  ... news_category
# 0  didnotaskforpaternityleavemywifebackedmesunilg...  ...        sports
# 1  itannoysthehelloutofmeianchappellurgesicctoban...  ...        sports
# 2  f1driversurviveshugecrashaftercarsplitsintotwo...  ...        sports
# 3  maradonasdoctorprobedoverinvoluntarymanslaught...  ...        sports
# 4  chrislynnsmashes20sixesscores154runsoff55balls...  ...        sports
#
# [5 rows x 3 columns]

# %%
df['compound'] = df['news_article'].apply(lambda x: vs.polarity_scores(x)['compound'])

# %%
df.head()
# Out:
#                                        news_headline  ... compound
# 0  didnotaskforpaternityleavemywifebackedmesunilg...  ...      0.0
# 1  itannoysthehelloutofmeianchappellurgesicctoban...  ...      0.0
# 2  f1driversurviveshugecrashaftercarsplitsintotwo...  ...      0.0
# 3  maradonasdoctorprobedoverinvoluntarymanslaught...  ...      0.0
# 4  chrislynnsmashes20sixesscores154runsoff55balls...  ...      0.0
#
# [5 rows x 4 columns]

# %%
df
# Out:
#                                         news_headline  ... compound
# 0   didnotaskforpaternityleavemywifebackedmesunilg...  ...      0.0
# 1   itannoysthehelloutofmeianchappellurgesicctoban...  ...      0.0
# 2   f1driversurviveshugecrashaftercarsplitsintotwo...  ...      0.0
# 3   maradonasdoctorprobedoverinvoluntarymanslaught...  ...      0.0
# 4   chrislynnsmashes20sixesscores154runsoff55balls...  ...      0.0
# 5   refereesavesmmafighterfromnearlyflashingherbre...  ...      0.0
# 6   jaspritbumrahkicks30yardfieldmarkerinangerduri...  ...      0.0
# 7   whatprotectiondofarmershavemontypanesaronindia...  ...      0.0
# 8   tysonrevealshesmokedmarijuanabeforethrowing193...  ...      0.0
# 9   maradonasdaughterbreaksdownasfootballteamgives...  ...      0.0
# 10  nocaptainwouldgivebumrah2overopeningspellkohli...  ...      0.0
# 11        warnerruledoutof3rdodit20iseriesduetoinjury  ...      0.0
# 12  ijustaskedhimoutofnowherekohlionpandyabowlinga...  ...      0.0
# 13  hadrohitbeenin2ndodiwewouldhaveplayedinbolderf...  ...      0.0
# 14  didnotthinkiwouldplaythe2ndodiafterabaddoseofv...  ...      0.0
# 15  messipayshistributerevealsmaradonasjerseyafter...  ...      0.0
# 16    viratkohliisbeinghastyinhisdecisionsashishnehra  ...      0.0
# 17  smithdidnottakeriskbutgotatonoff62ballsitissca...  ...      0.0
# 18  needtolookinmirrordonotwanttofeellikelaughings...  ...      0.0
# 19  fatolookintomanutdscavanissocialmediapostwhich...  ...      0.0
# 20  videoofpackedconcertsparkscovid19fearsrappersa...  ...      0.0
# 21  400peoplefoundillegallypartyingatusclubamidcov...  ...      0.0
# 22  modernatoseekusemergencyauthorisationforcovid1...  ...      0.0
# 23  whoarepartofjoebidensallwomenseniorwhcommunica...  ...      0.0
# 24  oicallowsitselftobeusedbyacertaincountryindiao...  ...      0.0
# 25  ukwomanwhospent6yearstravellingacrosseuropegoe...  ...      0.0
# 26  bidenfractureshisfoottrumpshareshisvideoandsay...  ...      0.0
# 27  indonesianvolcanoemitssmoke4kmintoskyaftererup...  ...      0.0
# 28  worldsstrictestcorporateresponsibilityplanreje...  ...      0.0
# 29  chinagovtpostsfakepicofaustraliansoldiermurder...  ...      0.0
# 30  israelusedelectronicdevicestoremotelykillscien...  ...      0.0
# 31      usmayseesurgeuponsurgeincoronaviruscasesfauci  ...      0.0
# 32     usreportedover40lakhcoronaviruscasesinnovember  ...      0.0
# 33  hopeuswillnoterectbarrierstocooperationchinaon...  ...      0.0
# 34  euhopingbidenwillclarifyuspositionondigitaltax...  ...      0.0
# 35  twittersuspendsthaipromonarchyaccountforplatfo...  ...      0.0
# 36  uptothemgovtonpakcooperatingwithindiasinitiati...  ...      0.0
# 37  pakpmimrankhanbriefedonregionalsecuritysituati...  ...      0.0
# 38  skoreasexprezchungetssuspendedjailsentenceford...  ...      0.0
# 39     8inmatesdeadover50injuredinsrilankanprisonriot  ...      0.0
# 40  rajmlakiranmaheshwaridiesaftertestingpositivef...  ...      0.0
# 41  stopthreateningshowgovernanceinsteadfadnavisto...  ...      0.0
# 42  28thrankstatetryingtoteach5thrankstatekcronupc...  ...      0.0
# 43  chandrababunaidu12otherssuspendedforadayfromap...  ...      0.0
# 44  deprivinglibertyevenforonedayisonetoomanyscong...  ...      0.0
# 45  cbienforcementdirectorateshouldbesenttoborders...  ...      0.0
# 46  willnotgivebjptickettomuslimcandidatektakamino...  ...      0.0
# 47  wewillfreehyderabadfromnizamculturecreateminii...  ...      0.0
# 48  bjpsharespropagandavsrealityvideoafterrahulstw...  ...      0.0
# 49  mamatatoldsupporterstorapewomensayswbbjpleader...  ...      0.0
# 50  deviannapurnaidolstolen100yrsagoisbeingbrought...  ...      0.0
# 51  bjprollsoutredcarpetforbillionairesdigsroadsfo...  ...      0.0
# 52  nevercalledfarmersprotestpoliticallymotivateda...  ...      0.0
# 53  farmersmadepositivecontributiontogdprethinkfar...  ...      0.0
# 54  votingfortrsissameasvotingforaimimbjpspokesperson  ...      0.0
# 55  willtakeactionagainstprovocativespeecheshydcpo...  ...      0.0
# 56  massivecycleofreligiousconversiongoingonunderg...  ...      0.0
# 57  congressendsupopposingcountrywhileopposingpmmo...  ...      0.0
# 58    bjpwilldevelophyderabadintoaglobalithubamitshah  ...      0.0
# 59  presidentkovindpmmodiextendgreetingsongurunana...  ...      0.0
#
# [60 rows x 4 columns]

# %%
df.to_csv('news.csv',index=False)

# %%
# !pip install streamlit
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.6/dist-packages (0.71.0)
# Requirement already satisfied: base58 in /usr/local/lib/python3.6/dist-packages (from streamlit) (2.0.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from streamlit) (20.4)
# Requirement already satisfied: validators in /usr/local/lib/python3.6/dist-packages (from streamlit) (0.18.1)
# Requirement already satisfied: botocore>=1.13.44 in /usr/local/lib/python3.6/dist-packages (from streamlit) (1.19.25)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from streamlit) (2.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from streamlit) (1.18.5)
# Requirement already satisfied: altair>=3.2.0 in /usr/local/lib/python3.6/dist-packages (from streamlit) (4.1.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.6/dist-packages (from streamlit) (0.5.0)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from streamlit) (3.12.4)
# Requirement already satisfied: toml in /usr/local/lib/python3.6/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from streamlit) (2.23.0)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.6/dist-packages (from streamlit) (1.5.1)
# Requirement already satisfied: blinker in /usr/local/lib/python3.6/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from streamlit) (1.16.25)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.6/dist-packages (from streamlit) (0.10.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.6/dist-packages (from streamlit) (7.0.0)
# Requirement already satisfied: enum-compat in /usr/local/lib/python3.6/dist-packages (from streamlit) (0.0.3)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.6/dist-packages (from streamlit) (7.1.2)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.6/dist-packages (from streamlit) (4.1.1)
# Requirement already satisfied: gitpython in /usr/local/lib/python3.6/dist-packages (from streamlit) (3.1.11)
# Requirement already satisfied: pandas>=0.21.0 in /usr/local/lib/python3.6/dist-packages (from streamlit) (1.1.4)
# Requirement already satisfied: astor in /usr/local/lib/python3.6/dist-packages (from streamlit) (0.8.1)
# Requirement already satisfied: tornado>=5.0 in /usr/local/lib/python3.6/dist-packages (from streamlit) (5.1.1)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.6/dist-packages (from streamlit) (0.14.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from packaging->streamlit) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->streamlit) (2.4.7)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from validators->streamlit) (4.4.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4; python_version != "3.4" in /usr/local/lib/python3.6/dist-packages (from botocore>=1.13.44->streamlit) (1.25.11)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from botocore>=1.13.44->streamlit) (0.10.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.6/dist-packages (from altair>=3.2.0->streamlit) (0.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from altair>=3.2.0->streamlit) (2.11.2)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from altair>=3.2.0->streamlit) (2.6.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from altair>=3.2.0->streamlit) (0.3)
# Requirement already satisfied: traitlets>=4.3.2 in /usr/local/lib/python3.6/dist-packages (from pydeck>=0.1.dev5->streamlit) (4.3.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.6/dist-packages (from pydeck>=0.1.dev5->streamlit) (7.5.1)
# Requirement already satisfied: ipykernel>=5.1.2; python_version >= "3.4" in /usr/local/lib/python3.6/dist-packages (from pydeck>=0.1.dev5->streamlit) (5.3.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf!=3.11,>=3.6.0->streamlit) (50.3.2)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->streamlit) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->streamlit) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->streamlit) (2020.11.8)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from tzlocal->streamlit) (2018.9)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->streamlit) (0.3.3)
# Requirement already satisfied: pathtools>=0.1.1 in /usr/local/lib/python3.6/dist-packages (from watchdog->streamlit) (0.1.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.6/dist-packages (from gitpython->streamlit) (4.0.5)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->altair>=3.2.0->streamlit) (1.1.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.3.2->pydeck>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.5.1)
# Requirement already satisfied: ipython>=4.0.0; python_version >= "3.3" in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.5.0)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (5.3.5)
# Requirement already satisfied: smmap<4,>=3.0.1 in /usr/local/lib/python3.6/dist-packages (from gitdb<5,>=4.0.1->gitpython->streamlit) (3.0.4)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.7.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.3.1)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (4.8.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (2.6.1)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.0.18)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=5.1.2; python_version >= "3.4"->pydeck>=0.1.dev5->streamlit) (20.0.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.9.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.5.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (5.6.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=4.0.0; python_version >= "3.3"->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (1.4.3)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (3.2.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.4.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit) (0.5.1)

# %%
# %%writefile app1.py
import streamlit as st
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB

df = pd.read_csv('https://raw.githubusercontent.com/gkesavamurthy/basics/main/news.csv')
df = pd.read_csv('https://raw.githubusercontent.com/gkesavamurthy/basics/main/news.csv')
df['comments'] = df['comments'].astype('unicode')
df['sentiment'] = df['sentiment'].astype('unicode')
x = df.iloc[:,1].values 
y = df.iloc[:,3].values 
st.title("Sentiment Analysis of Airbnb Reviews")
st.subheader('TFIFD Vectorizer')

text_model = Pipeline([('tfidf',TfidfVectorizer()),('model',MultinomialNB())])
text_model.fit(x,y)
message = st.text_area("Enter Text","Type Here ..")
op = text_model.predict([message])
if st.button("Predict"):
  st.title(op)
# Out:
# Writing app1.py

# %%
# !pip install pyngrok==4.1.1
# Out:
# Collecting pyngrok==4.1.1
#   Downloading https://files.pythonhosted.org/packages/e4/a9/de2e15c92eb3aa4a2646ce3a7542317eb69ac47f667578ce8bf916320847/pyngrok-4.1.1.tar.gz
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyngrok==4.1.1) (0.16.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.6/dist-packages (from pyngrok==4.1.1) (3.13)
# Building wheels for collected packages: pyngrok
#   Building wheel for pyngrok (setup.py) ... done
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-cp36-none-any.whl size=15971 sha256=1b211a775c09877699b008394f8ced8662b339591b11e55c0654e3d12d4ceb67
#   Stored in directory: /root/.cache/pip/wheels/97/71/0d/1695f7c8815c0beb3b5d9b35d6eec9243c87e6070fbe3977fa
# Successfully built pyngrok
# Installing collected packages: pyngrok
# Successfully installed pyngrok-4.1.1

# %%
from pyngrok import ngrok
url = ngrok.connect(port='8501')
url
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b057558cdccd> in <module>()
# ----> 1 from pyngrok import ngrok
#       2 url = ngrok.connect(port='8501')
#       3 url
#
# ModuleNotFoundError: No module named 'pyngrok'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !streamlit run app1.py &
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.2:8501
#   External URL: http://34.67.172.218:8501
# 2020-12-01 05:16:16.240 INFO    pyngrok.process: t=2020-12-01T05:16:16+0000 lvl=info msg="join connections" obj=join id=84f7d34b84ca l=127.0.0.1:8501 r=[2401:4900:4b56:bd94:2509:d263:619d:cca8]:58962
#
# 2020-12-01 05:16:16.637 INFO    pyngrok.process: t=2020-12-01T05:16:16+0000 lvl=info msg="join connections" obj=join id=2c72ef38aab9 l=127.0.0.1:8501 r=[2401:4900:4b56:bd94:2509:d263:619d:cca8]:58962
#
# 2020-12-01 05:16:16.644 INFO    pyngrok.process: t=2020-12-01T05:16:16+0000 lvl=info msg="join connections" obj=join id=399f30a5f29c l=127.0.0.1:8501 r=[2401:4900:4b56:bd94:2509:d263:619d:cca8]:58962
#
# 2020-12-01 05:16:16.664 INFO    pyngrok.process: t=2020-12-01T05:16:16+0000 lvl=info msg="join connections" obj=join id=831fd7d53521 l=127.0.0.1:8501 r=[2401:4900:4b56:bd94:2509:d263:619d:cca8]:58962
#
# 2020-12-01 05:16:20.552 INFO    pyngrok.process: t=2020-12-01T05:16:20+0000 lvl=info msg="join connections" obj=join id=57d1515f6581 l=127.0.0.1:8501 r=[2401:4900:4b56:bd94:2509:d263:619d:cca8]:58969
#
# 2020-12-01 05:21:22.562 INFO    pyngrok.process: t=2020-12-01T05:21:22+0000 lvl=info msg="received stop request" obj=app stopReq="{err:<nil> restart:false}"
#   Stopping...
